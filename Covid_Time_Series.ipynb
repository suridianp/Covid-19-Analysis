# %% [markdown]
# #Import Dataset

# %%
#Import Library
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #Get The Data from Gdrive

# %%
#mengambil data dari gdrive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ##Read Dataset

# %%
#menampilkan data csv yang diambil dari gdrive
PATH = '/content/drive/MyDrive/Eduwork/Covid19/covid_19_indonesia_time_series_all.csv'
df = pd.read_csv(PATH)
df
# Out:
#             Date Location ISO Code          Location  New Cases  New Deaths  \
# 0       3/1/2020             ID-JK       DKI Jakarta          2           0
# 1       3/2/2020             ID-JK       DKI Jakarta          2           0
# 2       3/2/2020               IDN         Indonesia          2           0
# 3       3/2/2020             ID-RI              Riau          1           0
# 4       3/3/2020             ID-JK       DKI Jakarta          2           0
# ...          ...               ...               ...        ...         ...
# 31817  9/15/2022             ID-SA    Sulawesi Utara         37           0
# 31818  9/15/2022             ID-SB    Sumatera Barat         13           0
# 31819  9/15/2022             ID-SS  Sumatera Selatan         16           0
# 31820  9/15/2022             ID-SU    Sumatera Utara         50           0
# 31821  9/16/2022               IDN         Indonesia       2358          27
#
#        New Recovered  New Active Cases  Total Cases  Total Deaths  \
# 0                  0                 2           39            20
# 1                  0                 2           41            20
# 2                  0                 2            2             0
# 3                  0                 1            1             0
# 4                  0                 2           43            20
# ...              ...               ...          ...           ...
# 31817              0                37        52770          1213
# 31818              3                10       104640          2371
# 31819              1                15        82198          3376
# 31820              5                45       158866          3288
# 31821           2997              -666      6405044        157876
#
#        Total Recovered  ...  Latitude New Cases per Million  \
# 0                   75  ... -6.204699                  0.18
# 1                   75  ... -6.204699                  0.18
# 2                    0  ... -0.789275                  0.01
# 3                    1  ...  0.511648                  0.16
# 4                   75  ... -6.204699                  0.18
# ...                ...  ...       ...                   ...
# 31817            50997  ...  1.259638                 14.01
# 31818           102066  ... -0.850253                  2.36
# 31819            78510  ... -3.216212                  1.95
# 31820           154924  ...  2.191894                  3.36
# 31821          6218708  ... -0.789275                  8.89
#
#        Total Cases per Million New Deaths per Million  \
# 0                         3.60                    0.0
# 1                         3.78                    0.0
# 2                         0.01                    0.0
# 3                         0.16                    0.0
# 4                         3.96                    0.0
# ...                        ...                    ...
# 31817                 19974.38                    0.0
# 31818                 18959.11                    0.0
# 31819                 10002.74                    0.0
# 31820                 10680.15                    0.0
# 31821                 24153.07                    0.1
#
#       Total Deaths per Million Total Deaths per 100rb Case Fatality Rate  \
# 0                         1.84                   0.18             51.28%
# 1                         1.84                   0.18             48.78%
# 2                         0.00                   0.00              0.00%
# 3                         0.00                   0.00              0.00%
# 4                         1.84                   0.18             46.51%
# ...                        ...                    ...                ...
# 31817                   459.14                  45.91              2.30%
# 31818                   429.59                  42.96              2.27%
# 31819                   410.83                  41.08              4.11%
# 31820                   221.04                  22.10              2.07%
# 31821                   595.34                  59.53              2.46%
#
#       Case Recovered Rate Growth Factor of New Cases  \
# 0                 192.31%                        NaN
# 1                 182.93%                       1.00
# 2                   0.00%                        NaN
# 3                 100.00%                        NaN
# 4                 174.42%                       1.00
# ...                   ...                        ...
# 31817              96.64%                       2.85
# 31818              97.54%                       6.50
# 31819              95.51%                       3.20
# 31820              97.52%                       1.92
# 31821              97.09%                       0.89
#
#        Growth Factor of New Deaths
# 0                              NaN
# 1                             1.00
# 2                              NaN
# 3                              NaN
# 4                             1.00
# ...                            ...
# 31817                         1.00
# 31818                         1.00
# 31819                         1.00
# 31820                         1.00
# 31821                         1.29
#
# [31822 rows x 38 columns]

# %%
df['Total Deaths'].sum()
# Out:
# 145259577

# %% [markdown]
# # Understanding and Preprocessing Dataset

# %% [markdown]
# ##Informasi Tipe Dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31822 entries, 0 to 31821
# Data columns (total 38 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Date                         31822 non-null  object
#  1   Location ISO Code            31822 non-null  object
#  2   Location                     31822 non-null  object
#  3   New Cases                    31822 non-null  int64
#  4   New Deaths                   31822 non-null  int64
#  5   New Recovered                31822 non-null  int64
#  6   New Active Cases             31822 non-null  int64
#  7   Total Cases                  31822 non-null  int64
#  8   Total Deaths                 31822 non-null  int64
#  9   Total Recovered              31822 non-null  int64
#  10  Total Active Cases           31822 non-null  int64
#  11  Location Level               31822 non-null  object
#  12  City or Regency              0 non-null      float64
#  13  Province                     30893 non-null  object
#  14  Country                      31822 non-null  object
#  15  Continent                    31822 non-null  object
#  16  Island                       30893 non-null  object
#  17  Time Zone                    30893 non-null  object
#  18  Special Status               4558 non-null   object
#  19  Total Regencies              31822 non-null  int64
#  20  Total Cities                 30921 non-null  float64
#  21  Total Districts              31822 non-null  int64
#  22  Total Urban Villages         30918 non-null  float64
#  23  Total Rural Villages         30893 non-null  float64
#  24  Area (km2)                   31822 non-null  int64
#  25  Population                   31822 non-null  int64
#  26  Population Density           31822 non-null  float64
#  27  Longitude                    31822 non-null  float64
#  28  Latitude                     31822 non-null  float64
#  29  New Cases per Million        31822 non-null  float64
#  30  Total Cases per Million      31822 non-null  float64
#  31  New Deaths per Million       31822 non-null  float64
#  32  Total Deaths per Million     31822 non-null  float64
#  33  Total Deaths per 100rb       31822 non-null  float64
#  34  Case Fatality Rate           31822 non-null  object
#  35  Case Recovered Rate          31822 non-null  object
#  36  Growth Factor of New Cases   29883 non-null  float64
#  37  Growth Factor of New Deaths  28375 non-null  float64
# dtypes: float64(14), int64(12), object(12)
# memory usage: 9.2+ MB

# %% [markdown]
# ##Unique Data

# %%
#cek unik data
df.nunique()
# Out:
# Date                             930
# Location ISO Code                 35
# Location                          35
# New Cases                       2591
# New Deaths                       405
# New Recovered                   2541
# New Active Cases                2562
# Total Cases                    22951
# Total Deaths                    6419
# Total Recovered                21124
# Total Active Cases              8412
# Location Level                     2
# City or Regency                    0
# Province                          34
# Country                            1
# Continent                          1
# Island                             7
# Time Zone                          3
# Special Status                     3
# Total Regencies                   18
# Total Cities                      10
# Total Districts                   35
# Total Urban Villages              33
# Total Rural Villages              34
# Area (km2)                        35
# Population                        35
# Population Density                35
# Longitude                         35
# Latitude                          35
# New Cases per Million           6753
# Total Cases per Million        27298
# New Deaths per Million           809
# Total Deaths per Million       13212
# Total Deaths per 100rb          6408
# Case Fatality Rate              1328
# Case Recovered Rate             6170
# Growth Factor of New Cases       682
# Growth Factor of New Deaths      380
# dtype: int64

# %% [markdown]
# ###Handling Unique Data

# %%
#handling uniq data dengan hapus kolom Country dan Continent
df.drop(["Country", "Continent"], axis=1, inplace=True)

# %% [markdown]
# ##Missing Value

# %%
#cek missing value
df.isnull().sum()
# Out:
# Date                               0
# Location ISO Code                  0
# Location                           0
# New Cases                          0
# New Deaths                         0
# New Recovered                      0
# New Active Cases                   0
# Total Cases                        0
# Total Deaths                       0
# Total Recovered                    0
# Total Active Cases                 0
# Location Level                     0
# City or Regency                31822
# Province                         929
# Island                           929
# Time Zone                        929
# Special Status                 27264
# Total Regencies                    0
# Total Cities                     901
# Total Districts                    0
# Total Urban Villages             904
# Total Rural Villages             929
# Area (km2)                         0
# Population                         0
# Population Density                 0
# Longitude                          0
# Latitude                           0
# New Cases per Million              0
# Total Cases per Million            0
# New Deaths per Million             0
# Total Deaths per Million           0
# Total Deaths per 100rb             0
# Case Fatality Rate                 0
# Case Recovered Rate                0
# Growth Factor of New Cases      1939
# Growth Factor of New Deaths     3447
# dtype: int64

# %% [markdown]
# ###Handling Missing Value

# %%
# Hapus kolom dengan missing value di atas 50%
threshold = len(df) * 0.5
df.dropna(thresh=threshold, axis=1, inplace=True)

# Handling missing value numeric data dengan rata-rata
columns_to_fill = ['Total Cities', 'Total Urban Villages', 'Total Rural Villages', 'Growth Factor of New Cases', 'Growth Factor of New Deaths']
# Isi missing value dengan rata-rata dari masing-masing kolom
for column in columns_to_fill:
    df[column].fillna(df[column].mean(), inplace=True)

# Handling missing value objek data dengan unknown
# Kolom yang akan diisi dengan 'Unknown'
columns_to_fill2 = ['Province', 'Island', 'Time Zone']
# Isi missing value dengan 'Unknown' untuk masing-masing kolom
for columns in columns_to_fill2:
    df[columns].fillna('Unknown', inplace=True)

# %% [markdown]
# ###Make Sure Nothing Missing Value in Data

# %%
#cek missing value kembali
df.isnull().sum()
# Out:
# Date                           0
# Location ISO Code              0
# Location                       0
# New Cases                      0
# New Deaths                     0
# New Recovered                  0
# New Active Cases               0
# Total Cases                    0
# Total Deaths                   0
# Total Recovered                0
# Total Active Cases             0
# Location Level                 0
# Province                       0
# Island                         0
# Time Zone                      0
# Total Regencies                0
# Total Cities                   0
# Total Districts                0
# Total Urban Villages           0
# Total Rural Villages           0
# Area (km2)                     0
# Population                     0
# Population Density             0
# Longitude                      0
# Latitude                       0
# New Cases per Million          0
# Total Cases per Million        0
# New Deaths per Million         0
# Total Deaths per Million       0
# Total Deaths per 100rb         0
# Case Fatality Rate             0
# Case Recovered Rate            0
# Growth Factor of New Cases     0
# Growth Factor of New Deaths    0
# dtype: int64

# %% [markdown]
# ##Outlier

# %%
#cek outlier

def detect_and_plot_outliers(df):
    # Menghitung IQR dan mendeteksi outlier
    outliers = pd.DataFrame()
    for col in df.select_dtypes(include=['float64', 'int64']).columns:
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR
        outliers_in_col = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
        outliers = pd.concat([outliers, outliers_in_col])

    # Membuat box plot untuk setiap kolom numerik
    df.select_dtypes(include=['float64', 'int64']).boxplot(figsize=(10, 8))
    plt.xticks(rotation=90)
    plt.show()

    return outliers

# %%
# Select numeric columns
numeric_df = df.select_dtypes(include=['number'])

# %%
# Deteksi dan plot outlier
outliers = detect_and_plot_outliers(numeric_df)

# %% [markdown]
# ###Handling Outlier

# %%
import matplotlib.pyplot as plt
from scipy.stats.mstats import winsorize

def handle_outliers(df, threshold=3, method='median'):
    """
    Handle outliers in a DataFrame by replacing them with the specified method.

    Parameters:
    - df: DataFrame containing the data.
    - threshold: Z-score threshold for identifying outliers (default is 3).
    - method: Method for replacing outliers ('median', 'mean', or 'winsorize').

    Returns:
    - DataFrame with outliers replaced according to the specified method.
    """
    # Display initial boxplot for all columns
    df.plot(kind='box', subplots=True, layout=(int(np.ceil(len(df.columns)/3)), 3), figsize=(15, 10))
    plt.suptitle('Boxplot of Columns Before Outlier Handling')
    plt.show()

    for column in df.columns:
        if np.issubdtype(df[column].dtype, np.number):
            z_scores = np.abs((df[column] - df[column].mean()) / df[column].std())

            if method == 'median':
                replace_value = df[column].median()
            elif method == 'mean':
                replace_value = df[column].mean()
            elif method == 'winsorize':
                winsorized_values = winsorize(df[column], limits=[0.05, 0.05])
                df[column] = winsorized_values
                continue  # Move to the next column
            else:
                raise ValueError("Invalid method. Use 'median', 'mean', or 'winsorize'.")

            df.loc[z_scores > threshold, column] = replace_value

    # Display boxplot after outlier handling
    df.plot(kind='box', subplots=True, layout=(int(np.ceil(len(df.columns)/3)), 3), figsize=(15, 10))
    plt.suptitle('Boxplot of Columns After Outlier Handling')
    plt.show()

    return df

numeric_df = handle_outliers(numeric_df, threshold=3, method='median')
# Out:
# <ipython-input-14-7aecd124104d>:36: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '23596.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[z_scores > threshold, column] = replace_value
# <ipython-input-14-7aecd124104d>:36: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '565.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[z_scores > threshold, column] = replace_value
# <ipython-input-14-7aecd124104d>:36: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '21027.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[z_scores > threshold, column] = replace_value

# %% [markdown]
# ##Duplicat Data

# %%
#cek data duplikat
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ##Change Tipe Data

# %%
#mengubah tipe data date
df['Date'] = pd.to_datetime(df['Date'])

# %%
#cek kembali info data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31822 entries, 0 to 31821
# Data columns (total 34 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Date                         31822 non-null  datetime64[ns]
#  1   Location ISO Code            31822 non-null  object
#  2   Location                     31822 non-null  object
#  3   New Cases                    31822 non-null  int64
#  4   New Deaths                   31822 non-null  int64
#  5   New Recovered                31822 non-null  int64
#  6   New Active Cases             31822 non-null  int64
#  7   Total Cases                  31822 non-null  int64
#  8   Total Deaths                 31822 non-null  int64
#  9   Total Recovered              31822 non-null  int64
#  10  Total Active Cases           31822 non-null  int64
#  11  Location Level               31822 non-null  object
#  12  Province                     31822 non-null  object
#  13  Island                       31822 non-null  object
#  14  Time Zone                    31822 non-null  object
#  15  Total Regencies              31822 non-null  int64
#  16  Total Cities                 31822 non-null  float64
#  17  Total Districts              31822 non-null  int64
#  18  Total Urban Villages         31822 non-null  float64
#  19  Total Rural Villages         31822 non-null  float64
#  20  Area (km2)                   31822 non-null  int64
#  21  Population                   31822 non-null  int64
#  22  Population Density           31822 non-null  float64
#  23  Longitude                    31822 non-null  float64
#  24  Latitude                     31822 non-null  float64
#  25  New Cases per Million        31822 non-null  float64
#  26  Total Cases per Million      31822 non-null  float64
#  27  New Deaths per Million       31822 non-null  float64
#  28  Total Deaths per Million     31822 non-null  float64
#  29  Total Deaths per 100rb       31822 non-null  float64
#  30  Case Fatality Rate           31822 non-null  object
#  31  Case Recovered Rate          31822 non-null  object
#  32  Growth Factor of New Cases   31822 non-null  float64
#  33  Growth Factor of New Deaths  31822 non-null  float64
# dtypes: datetime64[ns](1), float64(13), int64(12), object(8)
# memory usage: 8.3+ MB

# %%
#melihat kolom Case Fataity Rate
df["Case Fatality Rate"].unique()
df["Case Recovered Rate"].unique()

#mengubah data object Case Fatality Rate menjadi integer dengan membaginya per 100
df['Case Fatality Rate'] = df['Case Fatality Rate'].str.replace('%', '').astype(float)
df['Case Recovered Rate'] = df['Case Recovered Rate'].str.replace('%', '').astype(float)

# %%
#hapus indonesia
df = df[df['Location'] != 'Indonesia']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 30893 entries, 0 to 31820
# Data columns (total 34 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Date                         30893 non-null  datetime64[ns]
#  1   Location ISO Code            30893 non-null  object
#  2   Location                     30893 non-null  object
#  3   New Cases                    30893 non-null  int64
#  4   New Deaths                   30893 non-null  int64
#  5   New Recovered                30893 non-null  int64
#  6   New Active Cases             30893 non-null  int64
#  7   Total Cases                  30893 non-null  int64
#  8   Total Deaths                 30893 non-null  int64
#  9   Total Recovered              30893 non-null  int64
#  10  Total Active Cases           30893 non-null  int64
#  11  Location Level               30893 non-null  object
#  12  Province                     30893 non-null  object
#  13  Island                       30893 non-null  object
#  14  Time Zone                    30893 non-null  object
#  15  Total Regencies              30893 non-null  int64
#  16  Total Cities                 30893 non-null  float64
#  17  Total Districts              30893 non-null  int64
#  18  Total Urban Villages         30893 non-null  float64
#  19  Total Rural Villages         30893 non-null  float64
#  20  Area (km2)                   30893 non-null  int64
#  21  Population                   30893 non-null  int64
#  22  Population Density           30893 non-null  float64
#  23  Longitude                    30893 non-null  float64
#  24  Latitude                     30893 non-null  float64
#  25  New Cases per Million        30893 non-null  float64
#  26  Total Cases per Million      30893 non-null  float64
#  27  New Deaths per Million       30893 non-null  float64
#  28  Total Deaths per Million     30893 non-null  float64
#  29  Total Deaths per 100rb       30893 non-null  float64
#  30  Case Fatality Rate           30893 non-null  float64
#  31  Case Recovered Rate          30893 non-null  float64
#  32  Growth Factor of New Cases   30893 non-null  float64
#  33  Growth Factor of New Deaths  30893 non-null  float64
# dtypes: datetime64[ns](1), float64(15), int64(12), object(6)
# memory usage: 8.2+ MB

# %% [markdown]
# ##Korelasi Data

# %%
#cek korelasi data numerik dengan heatmap
# Memilih kolom numerik
correlation_matrix = df[['New Cases','New Deaths','New Recovered','New Active Cases','Population','Total Cities','Total Regencies','Total Districts','Total Urban Villages','Total Rural Villages','Area (km2)','Case Fatality Rate','Case Recovered Rate','Growth Factor of New Cases','Growth Factor of New Deaths']].corr()

# Membuat heatmap dari matriks korelasi
plt.figure(figsize=(12, 8))  # Atur ukuran gambar
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5, fmt='.2f')
# Menambahkan judul
plt.title('Correlation')

# Menampilkan heatmap
plt.show()
print(correlation_matrix)
# Out:
#                              New Cases  New Deaths  New Recovered  \
# New Cases                     1.000000    0.515777       0.754382
# New Deaths                    0.515777    1.000000       0.522108
# New Recovered                 0.754382    0.522108       1.000000
# New Active Cases              0.261928   -0.088060      -0.435547
# Population                    0.313525    0.333357       0.285932
# Total Cities                  0.253814    0.235043       0.232350
# Total Regencies               0.045859    0.183232       0.038569
# Total Districts               0.165070    0.240737       0.148852
# Total Urban Villages          0.197454    0.242714       0.179424
# Total Rural Villages          0.232993    0.276641       0.211971
# Area (km2)                   -0.088100   -0.055310      -0.081358
# Case Fatality Rate           -0.022434    0.002623      -0.021662
# Case Recovered Rate          -0.005481   -0.007156      -0.001887
# Growth Factor of New Cases   -0.008440   -0.017603      -0.020996
# Growth Factor of New Deaths   0.046961    0.142298       0.082588
#
#                              New Active Cases  Population  Total Cities  \
# New Cases                            0.261928    0.313525      0.253814
# New Deaths                          -0.088060    0.333357      0.235043
# New Recovered                       -0.435547    0.285932      0.232350
# New Active Cases                     1.000000    0.003260      0.002759
# Population                           0.003260    1.000000      0.757764
# Total Cities                         0.002759    0.757764      1.000000
# Total Regencies                     -0.000161    0.590492      0.432967
# Total Districts                      0.001570    0.811518      0.607126
# Total Urban Villages                 0.001692    0.762819      0.722390
# Total Rural Villages                 0.002018    0.756920      0.636057
# Area (km2)                          -0.000978   -0.090252     -0.170432
# Case Fatality Rate                   0.000460    0.090690      0.070223
# Case Recovered Rate                 -0.004537    0.034254      0.034326
# Growth Factor of New Cases           0.019633   -0.021583     -0.013536
# Growth Factor of New Deaths         -0.061135    0.054553      0.041686
#
#                              Total Regencies  Total Districts  \
# New Cases                           0.045859         0.165070
# New Deaths                          0.183232         0.240737
# New Recovered                       0.038569         0.148852
# New Active Cases                   -0.000161         0.001570
# Population                          0.590492         0.811518
# Total Cities                        0.432967         0.607126
# Total Regencies                     1.000000         0.914343
# Total Districts                     0.914343         1.000000
# Total Urban Villages                0.725882         0.767139
# Total Rural Villages                0.806026         0.865854
# Area (km2)                          0.417472         0.333483
# Case Fatality Rate                  0.049683         0.063080
# Case Recovered Rate                -0.019799         0.006419
# Growth Factor of New Cases         -0.001685        -0.005757
# Growth Factor of New Deaths         0.026176         0.035512
#
#                              Total Urban Villages  Total Rural Villages  \
# New Cases                                0.197454              0.232993
# New Deaths                               0.242714              0.276641
# New Recovered                            0.179424              0.211971
# New Active Cases                         0.001692              0.002018
# Population                               0.762819              0.756920
# Total Cities                             0.722390              0.636057
# Total Regencies                          0.725882              0.806026
# Total Districts                          0.767139              0.865854
# Total Urban Villages                     1.000000              0.760386
# Total Rural Villages                     0.760386              1.000000
# Area (km2)                              -0.092102              0.226505
# Case Fatality Rate                       0.080187              0.078426
# Case Recovered Rate                      0.024593             -0.000907
# Growth Factor of New Cases              -0.012371             -0.011739
# Growth Factor of New Deaths              0.044763              0.041425
#
#                              Area (km2)  Case Fatality Rate  \
# New Cases                     -0.088100           -0.022434
# New Deaths                    -0.055310            0.002623
# New Recovered                 -0.081358           -0.021662
# New Active Cases              -0.000978            0.000460
# Population                    -0.090252            0.090690
# Total Cities                  -0.170432            0.070223
# Total Regencies                0.417472            0.049683
# Total Districts                0.333483            0.063080
# Total Urban Villages          -0.092102            0.080187
# Total Rural Villages           0.226505            0.078426
# Area (km2)                     1.000000           -0.039810
# Case Fatality Rate            -0.039810            1.000000
# Case Recovered Rate           -0.028023            0.526679
# Growth Factor of New Cases     0.000816           -0.005879
# Growth Factor of New Deaths   -0.013682           -0.005570
#
#                              Case Recovered Rate  Growth Factor of New Cases  \
# New Cases                              -0.005481                   -0.008440
# New Deaths                             -0.007156                   -0.017603
# New Recovered                          -0.001887                   -0.020996
# New Active Cases                       -0.004537                    0.019633
# Population                              0.034254                   -0.021583
# Total Cities                            0.034326                   -0.013536
# Total Regencies                        -0.019799                   -0.001685
# Total Districts                         0.006419                   -0.005757
# Total Urban Villages                    0.024593                   -0.012371
# Total Rural Villages                   -0.000907                   -0.011739
# Area (km2)                             -0.028023                    0.000816
# Case Fatality Rate                      0.526679                   -0.005879
# Case Recovered Rate                     1.000000                   -0.009428
# Growth Factor of New Cases             -0.009428                    1.000000
# Growth Factor of New Deaths            -0.004767                    0.007475
#
#                              Growth Factor of New Deaths
# New Cases                                       0.046961
# New Deaths                                      0.142298
# New Recovered                                   0.082588
# New Active Cases                               -0.061135
# Population                                      0.054553
# Total Cities                                    0.041686
# Total Regencies                                 0.026176
# Total Districts                                 0.035512
# Total Urban Villages                            0.044763
# Total Rural Villages                            0.041425
# Area (km2)                                     -0.013682
# Case Fatality Rate                             -0.005570
# Case Recovered Rate                            -0.004767
# Growth Factor of New Cases                      0.007475
# Growth Factor of New Deaths                     1.000000

# %% [markdown]
# #Save Dataset After Preprocessing Dataset

# %%
#menyimpan df yang telah dilakukan preprocessing data
df.to_csv('covid_19_indonesia_preprocessed.csv', index=False)

# %% [markdown]
# #Describe Dataset

# %%
#describe data
df.describe()
# Out:
#                                 Date     New Cases    New Deaths  \
# count                          30893  30893.000000  30893.000000
# mean   2021-06-18 01:54:03.647428352    207.079565      5.108568
# min              2020-03-01 00:00:00      0.000000      0.000000
# 25%              2020-11-03 00:00:00      3.000000      0.000000
# 50%              2021-06-18 00:00:00     24.000000      0.000000
# 75%              2022-01-31 00:00:00    113.000000      3.000000
# max              2022-09-15 00:00:00  16251.000000    545.000000
# std                              NaN    771.874452     22.344819
#
#        New Recovered  New Active Cases   Total Cases  Total Deaths  \
# count   30893.000000      30893.000000  3.089300e+04  30893.000000
# mean      200.840093          1.130903  8.204233e+04   2354.077202
# min         0.000000     -19976.000000  1.000000e+00      0.000000
# 25%         2.000000        -12.000000  4.905000e+03    121.000000
# 50%        18.000000          0.000000  2.268400e+04    539.000000
# 75%       106.000000         17.000000  6.467900e+04   1885.000000
# max     23872.000000      13108.000000  1.412511e+06  33489.000000
# std       813.941207        558.652362  1.852533e+05   5471.624776
#
#        Total Recovered  Total Active Cases  Total Regencies  ...  \
# count     3.089300e+04        30893.000000     30893.000000  ...
# mean      7.681409e+04         2874.153303        12.240054  ...
# min       0.000000e+00        -2343.000000         1.000000  ...
# 25%       3.685000e+03           75.000000         7.000000  ...
# 50%       1.952100e+04          519.000000        11.000000  ...
# 75%       6.116000e+04         2025.000000        15.000000  ...
# max       1.386134e+06       188636.000000        29.000000  ...
# std       1.778584e+05         9003.791351         7.363519  ...
#
#            Latitude  New Cases per Million  Total Cases per Million  \
# count  30893.000000           30893.000000             30893.000000
# mean      -2.783911              28.197475             11520.430172
# min       -8.682205               0.000000                 0.020000
# 25%       -6.204699               0.760000              1287.870000
# 50%       -2.993595               5.510000              6786.780000
# 75%        0.212037              22.110000             14250.120000
# max        4.225615            1459.040000            130231.620000
# std        3.646021              75.073338             16651.867316
#
#        New Deaths per Million  Total Deaths per Million  \
# count            30893.000000              30893.000000
# mean                 0.640289                289.489398
# min                  0.000000                  0.000000
# 25%                  0.000000                 38.450000
# 50%                  0.000000                158.090000
# 75%                  0.520000                387.730000
# max                 63.800000               1632.600000
# std                  1.951164                366.431814
#
#        Total Deaths per 100rb  Case Fatality Rate  Case Recovered Rate  \
# count            30893.000000        30893.000000         30893.000000
# mean                28.948904            4.092969            87.076151
# min                  0.000000            0.000000             0.000000
# 25%                  3.850000            1.860000            76.500000
# 50%                 15.810000            2.630000            90.390000
# 75%                 38.770000            3.740000            96.640000
# max                163.260000         1000.000000         11100.000000
# std                 36.643191           14.605512           144.725339
#
#        Growth Factor of New Cases  Growth Factor of New Deaths
# count                30893.000000                 30893.000000
# mean                     1.335549                     1.031503
# min                      0.000000                     0.000000
# 25%                      0.670000                     0.900000
# 50%                      1.000000                     1.000000
# 75%                      1.326795                     1.033834
# max                    175.000000                   134.500000
# std                      2.634139                     1.288845
#
# [8 rows x 28 columns]

# %% [markdown]
# #Eksplorasi Visualisaasi Data Analysis

# %% [markdown]
# ##Time Series

# %% [markdown]
# ###Monthly New Cases

# %%
# Set kolom Date sebagai index
df.set_index('Date', inplace=True)

# %%
# Resample data per bulan dan hitung jumlah kasus baru setiap bulan
monthly_cases = df['New Cases'].resample('M').sum()

# Buat grafik tren garis bulanan
plt.figure(figsize=(12, 6))
plt.plot(monthly_cases.index, monthly_cases.values, marker='o', linestyle='-', color='orange')
plt.xlabel('Date')
plt.ylabel('Monthly New Cases')
plt.title('Monthly New COVID-19 Cases')
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ###Monthly New Deaths

# %%
# Resample data per bulan dan hitung kematian kasus baru setiap bulan
monthly_deaths = df['New Deaths'].resample('M').sum()

# Buat grafik tren garis bulanan
plt.figure(figsize=(12, 6))
plt.plot(monthly_deaths.index, monthly_deaths.values, marker='o', linestyle='-', color='red')
plt.xlabel('Date')
plt.ylabel('Monthly New Deaths')
plt.title('Monthly New COVID-19 Deaths')
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ###Monthly New Recovered

# %%
# Resample data per bulan dan hitung kasus recorvery baru setiap bulan
monthly_deaths = df['New Recovered'].resample('M').sum()

# Buat grafik tren garis bulanan
plt.figure(figsize=(12, 6))
plt.plot(monthly_deaths.index, monthly_deaths.values, marker='o', linestyle='-', color='green')
plt.xlabel('Date')
plt.ylabel('Monthly New Recovered')
plt.title('Monthly New COVID-19 Recovered')
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##BarChart Top 10 in Location

# %% [markdown]
# ###Hapus Indonesia

# %%
#melihat kolom location
df["Location"].unique()
# Out:
# array(['DKI Jakarta', 'Riau', 'Jawa Barat', 'Banten', 'Jawa Tengah',
#        'Sulawesi Tenggara', 'Bali', 'Kalimantan Timur',
#        'Daerah Istimewa Yogyakarta', 'Sumatera Utara', 'Jawa Timur',
#        'Kepulauan Riau', 'Sulawesi Selatan', 'Jambi', 'Maluku', 'Papua',
#        'Maluku Utara', 'Sumatera Selatan', 'Aceh', 'Kalimantan Tengah',
#        'Lampung', 'Sulawesi Tengah', 'Sulawesi Utara', 'Sumatera Barat',
#        'Papua Barat', 'Kalimantan Utara', 'Sulawesi Barat',
#        'Kalimantan Barat', 'Kalimantan Selatan',
#        'Kepulauan Bangka Belitung', 'Bengkulu', 'Nusa Tenggara Barat',
#        'Nusa Tenggara Timur', 'Gorontalo'], dtype=object)

# %% [markdown]
# ###Total Cases all Location

# %%
#Total Cases in every location
location_cases = df.groupby('Location')['Total Cases'].sum().reset_index()
location_cases
# Out:
#                       Location  Total Cases
# 0                         Aceh     19962180
# 1                         Bali     66247623
# 2                       Banten    100598017
# 3                     Bengkulu     12347482
# 4                  DKI Jakarta    545806047
# 5   Daerah Istimewa Yogyakarta     86090207
# 6                    Gorontalo      6746166
# 7                        Jambi     15700629
# 8                   Jawa Barat    439196053
# 9                  Jawa Tengah    273046506
# 10                  Jawa Timur    239912685
# 11            Kalimantan Barat     23403342
# 12          Kalimantan Selatan     39485248
# 13           Kalimantan Tengah     25507275
# 14            Kalimantan Timur     89582475
# 15            Kalimantan Utara     18782628
# 16   Kepulauan Bangka Belitung     26613493
# 17              Kepulauan Riau     29043850
# 18                     Lampung     28891786
# 19                      Maluku      9046656
# 20                Maluku Utara      6781984
# 21         Nusa Tenggara Barat     15887423
# 22         Nusa Tenggara Timur     34710372
# 23                       Papua     22285548
# 24                 Papua Barat     13634548
# 25                        Riau     68594950
# 26              Sulawesi Barat      6865029
# 27            Sulawesi Selatan     66922249
# 28             Sulawesi Tengah     24193556
# 29           Sulawesi Tenggara     12244125
# 30              Sulawesi Utara     21715953
# 31              Sumatera Barat     49292155
# 32            Sumatera Selatan     34483096
# 33              Sumatera Utara     60912221

# %% [markdown]
# ###Save total cases in all location

# %%
#save Location_cases in csv
location_cases.to_csv('updatelocation_cases.csv', index=False)

# %% [markdown]
# ###Gruping Top 10 Total Cases by Location

# %%
# Group by location dan hitung total kasus per lokasi
location_cases = df.groupby('Location')['Total Cases'].sum().reset_index()

# Sortir data berdasarkan total kasus secara menurun dan ambil 10 teratas
top_10_location_cases = location_cases.sort_values(by='Total Cases', ascending=False).head(10)
top_10_location_cases
# Out:
#                       Location  Total Cases
# 4                  DKI Jakarta    545806047
# 8                   Jawa Barat    439196053
# 9                  Jawa Tengah    273046506
# 10                  Jawa Timur    239912685
# 2                       Banten    100598017
# 14            Kalimantan Timur     89582475
# 5   Daerah Istimewa Yogyakarta     86090207
# 25                        Riau     68594950
# 27            Sulawesi Selatan     66922249
# 1                         Bali     66247623

# %% [markdown]
# ###Visualisasi Barchart Top 10 Total Cases

# %%
# Membuat bar chart untuk top 10 lokasi dengan total kasus terbanyak
plt.figure(figsize=(20, 10))
sns.barplot(data=top_10_location_cases, x='Location', y='Total Cases', dodge=True, edgecolor='black', color='orange')

plt.xlabel('Location')  # Ubah label x-axis menjadi 'Location'
plt.ylabel('Total Cases')  # Ubah label y-axis menjadi 'Total Cases'
plt.title('Top 10 Locations by Total Cases')  # Ubah judul plot
plt.xticks(rotation=45)  # Rotasi label x-axis agar lebih mudah dibaca
plt.tight_layout()  # Sesuaikan tata letak agar label tidak terpotong
plt.show()

# %% [markdown]
# ###Save data top 10 total cases in csv

# %%
#menyimpan data top_10_location_cases dalam bentuk csv
top_10_location_cases.to_csv('top_10_location_cases.csv', index=False)

# %% [markdown]
# ###Gruping Top 10 Total Deaths by Location

# %%
# Group by location dan hitung total kematian per lokasi
location_death = df.groupby('Location')['Total Deaths'].sum().reset_index()

# Sortir data berdasarkan total kematian secara menurun dan ambil 10 teratas
top_10_location_deaths = location_death.sort_values(by='Total Deaths', ascending=False).head(10)
top_10_location_deaths
# Out:
#                       Location  Total Deaths
# 10                  Jawa Timur      15384287
# 9                  Jawa Tengah      14972030
# 4                  DKI Jakarta       7672746
# 8                   Jawa Barat       7097250
# 14            Kalimantan Timur       2644808
# 5   Daerah Istimewa Yogyakarta       2484820
# 1                         Bali       2017352
# 25                        Riau       2012582
# 18                     Lampung       1796384
# 32            Sumatera Selatan       1582127

# %% [markdown]
# ###Visualisasi Barchart Top 10 Total Deaths

# %%
# Membuat bar chart untuk top 10 lokasi dengan total kasus terbanyak
plt.figure(figsize=(20, 10))
sns.barplot(data=top_10_location_deaths, x='Location', y='Total Deaths', dodge=True, edgecolor='black', color='red')

plt.xlabel('Location')  # Ubah label x-axis menjadi 'Location'
plt.ylabel('Total Deaths')  # Ubah label y-axis menjadi 'Total Cases'
plt.title('Top 10 Locations by Total Deaths')  # Ubah judul plot
plt.xticks(rotation=45)  # Rotasi label x-axis agar lebih mudah dibaca
plt.tight_layout()  # Sesuaikan tata letak agar label tidak terpotong
plt.show()

# %% [markdown]
# ###Save data top 10 total deaths in csv

# %%
#menyimpan data top_10_location_deaths dalam bentuk csv
top_10_location_deaths.to_csv('top_10_location_deaths.csv', index=False)

# %% [markdown]
# ###Gruping Top 10 Total Recovered by Location

# %%
# Group by location dan hitung total kematian per lokasi
location_recovery = df.groupby('Location')['Total Recovered'].sum().reset_index()

# Sortir data berdasarkan total kematian secara menurun dan ambil 10 teratas
top_10_location_recovery = location_recovery.sort_values(by='Total Recovered', ascending=False).head(10)
top_10_location_recovery
# Out:
#                       Location  Total Recovered
# 4                  DKI Jakarta        526474096
# 8                   Jawa Barat        412874932
# 9                  Jawa Tengah        246232049
# 10                  Jawa Timur        220227772
# 2                       Banten         95323211
# 14            Kalimantan Timur         84393243
# 5   Daerah Istimewa Yogyakarta         79579777
# 25                        Riau         64845902
# 27            Sulawesi Selatan         63624765
# 1                         Bali         62075015

# %% [markdown]
# ###Visualisasi Barchart Top 10 Total Recovered

# %%
# Membuat bar chart untuk top 10 lokasi dengan total recovery terbanyak
plt.figure(figsize=(20, 10))
sns.barplot(data=top_10_location_recovery, x='Location', y='Total Recovered', dodge=True, edgecolor='black', color='green')

plt.xlabel('Location')  # Ubah label x-axis menjadi 'Location'
plt.ylabel('Total Recovered')  # Ubah label y-axis menjadi 'Total Cases'
plt.title('Top 10 Locations by Total Recovered')  # Ubah judul plot
plt.xticks(rotation=45)  # Rotasi label x-axis agar lebih mudah dibaca
plt.tight_layout()  # Sesuaikan tata letak agar label tidak terpotong
plt.show()

# %% [markdown]
# ###Save data top 10 total recovered in csv

# %%
#menyimpan data top_10_location_recovery dalam bentuk csv
top_10_location_recovery.to_csv('top_10_location_recovery.csv', index=False)

# %% [markdown]
# ##Total Cases Distribution

# %%
import seaborn as sns

# Membuat histogram untuk distribusi kasus per juta
plt.figure(figsize=(12, 6))
sns.histplot(df['Total Cases per Million'], bins=30, kde=True, color='orange')
plt.xlabel('Total Cases per Million')
plt.ylabel('Frequency')
plt.title('Distribution of Total Cases per Million')
plt.tight_layout()
plt.show()

# %% [markdown]
# ##Ratio Case Fatality and Recovered Rate

# %%
# Mengelompokkan data berdasarkan lokasi dan menghitung rasio kematian dan pemulihan
location_stats = df.groupby('Location').agg({
    'Total Deaths': 'sum',
    'Total Recovered': 'sum',
    'Total Cases': 'sum'
}).reset_index()
location_stats['Case Fatality Rate'] = location_stats['Total Deaths'] / location_stats['Total Cases'] * 100
location_stats['Case Recovered Rate'] = location_stats['Total Recovered'] / location_stats['Total Cases'] * 100

# Membuat bar chart untuk rasio kematian dan pemulihan
plt.figure(figsize=(20, 10))
sns.barplot(data=location_stats.sort_values(by='Total Cases', ascending=False).head(10), x='Location', y='Case Fatality Rate', color='red', label='Fatality Rate')
sns.barplot(data=location_stats.sort_values(by='Total Cases', ascending=False).head(10), x='Location', y='Case Recovered Rate', color='green', label='Recovered Rate', alpha=0.5)
plt.xlabel('Location')
plt.ylabel('Rate (%)')
plt.title('Case Fatality and Recovered Rates by Top 10 Locations')
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# #Clustering

# %% [markdown]
# ##Find cluster optimal with elbow method

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
# Normalisasi data total kasus
scaler = StandardScaler()
df['Total Cases Scaled'] = scaler.fit_transform(df[['Total Cases']])

# Elbow method untuk menentukan jumlah cluster optimal
inertia = []
k_range = range(1, 11)

for k in k_range:
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(df[['Total Cases Scaled']])
    inertia.append(kmeans.inertia_)

# Plot Elbow method
plt.figure(figsize=(12, 6))
plt.plot(k_range, inertia, marker='o')
plt.xlabel('Number of clusters (k)')
plt.ylabel('Inertia')
plt.title('Elbow Method for Optimal k')
plt.xticks(k_range)
plt.grid(True)
plt.show()
# Out:
# <ipython-input-40-fa85f3031819>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Total Cases Scaled'] = scaler.fit_transform(df[['Total Cases']])
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %% [markdown]
# ##Visualisasi Clustering with k=2

# %%
# Menentukan jumlah cluster optimal dari plot Elbow
optimal_k = 2

# Melakukan clustering menggunakan K-Means dengan jumlah cluster optimal
kmeans = KMeans(n_clusters=optimal_k, random_state=42)
df['Cluster'] = kmeans.fit_predict(df[['Total Cases Scaled']])

# Palet warna khusus untuk cluster
palette = {0: 'green', 1: 'red'}

# Visualisasi hasil clustering
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='New Deaths', y='New Cases', hue='Cluster', palette=palette, s=100)
plt.xlabel('New Deaths')
plt.ylabel('New Cases')
plt.title('Clustering of Condition COVID-19 Cases')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# Menampilkan hasil clustering
print(df)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# <ipython-input-49-804c9d8d3825>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Cluster'] = kmeans.fit_predict(df[['Total Cases Scaled']])
#            Location ISO Code           Location  New Cases  New Deaths  \
# Date
# 2020-03-01             ID-JK        DKI Jakarta          2           0
# 2020-03-02             ID-JK        DKI Jakarta          2           0
# 2020-03-02             ID-RI               Riau          1           0
# 2020-03-03             ID-JK        DKI Jakarta          2           0
# 2020-03-03             ID-JB         Jawa Barat          1           1
# ...                      ...                ...        ...         ...
# 2022-09-15             ID-SG  Sulawesi Tenggara          2           0
# 2022-09-15             ID-SA     Sulawesi Utara         37           0
# 2022-09-15             ID-SB     Sumatera Barat         13           0
# 2022-09-15             ID-SS   Sumatera Selatan         16           0
# 2022-09-15             ID-SU     Sumatera Utara         50           0
#
#             New Recovered  New Active Cases  Total Cases  Total Deaths  \
# Date
# 2020-03-01              0                 2           39            20
# 2020-03-02              0                 2           41            20
# 2020-03-02              0                 1            1             0
# 2020-03-03              0                 2           43            20
# 2020-03-03              0                 0            1             1
# ...                   ...               ...          ...           ...
# 2022-09-15              0                 2        25693           569
# 2022-09-15              0                37        52770          1213
# 2022-09-15              3                10       104640          2371
# 2022-09-15              1                15        82198          3376
# 2022-09-15              5                45       158866          3288
#
#             Total Recovered  Total Active Cases  ... Total Cases per Million  \
# Date                                             ...
# 2020-03-01               75                 -56  ...                    3.60
# 2020-03-02               75                 -54  ...                    3.78
# 2020-03-02                1                   0  ...                    0.16
# 2020-03-03               75                 -52  ...                    3.96
# 2020-03-03               60                 -60  ...                    0.02
# ...                     ...                 ...  ...                     ...
# 2022-09-15            25090                  34  ...                 9748.96
# 2022-09-15            50997                 560  ...                19974.38
# 2022-09-15           102066                 203  ...                18959.11
# 2022-09-15            78510                 312  ...                10002.74
# 2022-09-15           154924                 654  ...                10680.15
#
#            New Deaths per Million Total Deaths per Million  \
# Date
# 2020-03-01                   0.00                     1.84
# 2020-03-02                   0.00                     1.84
# 2020-03-02                   0.00                     0.00
# 2020-03-03                   0.00                     1.84
# 2020-03-03                   0.02                     0.02
# ...                           ...                      ...
# 2022-09-15                   0.00                   215.90
# 2022-09-15                   0.00                   459.14
# 2022-09-15                   0.00                   429.59
# 2022-09-15                   0.00                   410.83
# 2022-09-15                   0.00                   221.04
#
#            Total Deaths per 100rb  Case Fatality Rate  Case Recovered Rate  \
# Date
# 2020-03-01                   0.18               51.28               192.31
# 2020-03-02                   0.18               48.78               182.93
# 2020-03-02                   0.00                0.00               100.00
# 2020-03-03                   0.18               46.51               174.42
# 2020-03-03                   0.00              100.00              6000.00
# ...                           ...                 ...                  ...
# 2022-09-15                  21.59                2.21                97.65
# 2022-09-15                  45.91                2.30                96.64
# 2022-09-15                  42.96                2.27                97.54
# 2022-09-15                  41.08                4.11                95.51
# 2022-09-15                  22.10                2.07                97.52
#
#             Growth Factor of New Cases  Growth Factor of New Deaths  \
# Date
# 2020-03-01                    1.326795                     1.033834
# 2020-03-02                    1.000000                     1.000000
# 2020-03-02                    1.326795                     1.033834
# 2020-03-03                    1.000000                     1.000000
# 2020-03-03                    1.326795                     1.033834
# ...                                ...                          ...
# 2022-09-15                    1.326795                     1.000000
# 2022-09-15                    2.850000                     1.000000
# 2022-09-15                    6.500000                     1.000000
# 2022-09-15                    3.200000                     1.000000
# 2022-09-15                    1.920000                     1.000000
#
#             Total Cases Scaled  Cluster
# Date
# 2020-03-01           -0.442662        0
# 2020-03-02           -0.442652        0
# 2020-03-02           -0.442867        0
# 2020-03-03           -0.442641        0
# 2020-03-03           -0.442867        0
# ...                        ...      ...
# 2022-09-15           -0.304179        0
# 2022-09-15           -0.158015        0
# 2022-09-15            0.121985        0
# 2022-09-15            0.000840        0
# 2022-09-15            0.414702        0
#
# [30893 rows x 35 columns]

# %% [markdown]
# ##Analysis in Cluster 0 and Cluster 1

# %% [markdown]
# ###Analysis Cluster 0

# %%
#perhitungan rata-rata New Deaths dan New Cases pada Cluster 0
cluster_0_data = df[df['Cluster'] == 0]
average_new_deaths_cluster_0 = cluster_0_data['New Deaths'].mean()
average_new_cases_cluster_0 = cluster_0_data['New Cases'].mean()

print("Rata-rata New Deaths pada Cluster 0:", average_new_deaths_cluster_0)
print("Rata-rata New Cases pada Cluster 0:", average_new_cases_cluster_0)
# Out:
# Rata-rata New Deaths pada Cluster 0: 4.303114988753323
# Rata-rata New Cases pada Cluster 0: 144.3280621634517

# %% [markdown]
# ###Analysis Cluster 1

# %%
#perhitungan rata-rata New Deaths dan New Cases pada Cluster 1
cluster_1_data = df[df['Cluster'] == 1]
average_new_deaths_cluster_1 = cluster_1_data['New Deaths'].mean()
average_new_cases_cluster_1 = cluster_1_data['New Cases'].mean()

print("Rata-rata New Deaths pada Cluster 1:", average_new_deaths_cluster_1)
print("Rata-rata New Cases pada Cluster 1:", average_new_cases_cluster_1)
# Out:
# Rata-rata New Deaths pada Cluster 1: 20.34622823984526
# Rata-rata New Cases pada Cluster 1: 1394.2198581560283

# %% [markdown]
# ###Location in CLuster 1

# %%
#Location mana saja yang masuk kedalam Cluster 1
cluster_1_locations = df[df['Cluster'] == 1]['Location'].unique()
print("Location yang masuk kedalam Cluster 1:", cluster_1_locations)
# Out:
# Location yang masuk kedalam Cluster 1: ['DKI Jakarta' 'Jawa Barat' 'Jawa Tengah' 'Jawa Timur']

# %%
df['Total Deaths'].sum()
# Out:
# 72724507
